# %% [markdown]
# # **Project Name**    - Explanatory Data Analysis on Hotel Booking Data

# %% [markdown]
#  **Project Type**    - EDA
# **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
# The hotel booking dataset contains reservation details for city and resort hotels, covering booking trends, cancellations, customer demographics, and pricing. It includes key variables like lead time, arrival dates, stay duration, market segment, and reservation status. The data shows that city hotels have higher bookings, while cancellations are more common for online reservations with long lead times. Peak booking periods are in summer, with higher ADR (price per night) during high-demand seasons. Insights from this data help optimize pricing, cancellation policies, and marketing strategies to improve hotel revenue.

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Nethra0503/Hotel_Booking_Data_Analysis_Project.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The problem is to perform an Exploratory Data Analysis (EDA) on hotel booking data to uncover trends, patterns, and relationships between various factors like cancellations, booking sources, and customer demographics. This analysis aims to provide actionable insights that can improve booking strategies, optimize room utilization, and inform pricing decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/Hotel Bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.iloc[10:13,8:]
# Out:
#     stays_in_week_nights  adults  children  babies meal country  \
# 10                     4       2       0.0       0   BB     PRT
# 11                     4       2       0.0       0   HB     PRT
# 12                     4       2       0.0       0   BB     USA
#
#    market_segment distribution_channel  is_repeated_guest  \
# 10      Online TA                TA/TO                  0
# 11      Online TA                TA/TO                  0
# 12      Online TA                TA/TO                  0
#
#     previous_cancellations  ...  deposit_type  agent company  \
# 10                       0  ...    No Deposit  240.0     NaN
# 11                       0  ...    No Deposit  240.0     NaN
# 12                       0  ...    No Deposit  240.0     NaN
#
#     days_in_waiting_list customer_type    adr  required_car_parking_spaces  \
# 10                     0     Transient  123.0                            0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %%
list(df.columns)
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %%
df=df.drop_duplicates()
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.duplicated().value_counts()
# Out:
# False    87396
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
plt.show()

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  hotel - contains value like resort hotel and city hotel
#
# *   hotel - contains value like resort hotel and city hotel
# *   is_canceled- contains integer value as 1,0 to represent if the booking was
#   cancelled or not respectively.
# *   lead_time - depicts the no of days elapsed between entering date of booking to pms and arrival date
# *   arrival_date_year - year of arrival
# *   arrival_date_month - month of arrival date
# *   arrival_date_week_number- week number for arrival date
# *   arrival_date_day_of_month -day of arrival
# *   stays_in_weekend_nights- no of weekend nights the guest stayed in hotel
# *   stays_in_week_nights - no of weekday nights the guest stayed in hotel
# *   adults - no of adults
# *   children - no of children
# *   babies - no of babies
# *   meal -  type of meal opted by the guest
# *   country - country code
# *   market_segment - to which segment the customer belongs to.
# *   distribution_channel - mode of accessing the stay.
# *   is_repeated_guest - guest coming for first time or not.
# *   previous_cancellations - was there any cancellation before.
# *   reserved_room_type - type of room
# *   assigned_room_type - type of room assigned
# *   booking_changes - no of changes made on booking
# *   deposit_type - type of depost made.
# *   agent- boked through agent
# *   days_in_waiting_list - no of days in waiting list.
# *   customer_type - type of customer
# *   required_car_parking_spaces - status of car parking needed or not needed
# *   total_of_special_requests - no of additional services required
# *   reservation_status - reservation of status
# *   reservation_status_date - date of specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
df['children'].value_counts()
# Out:
# children
# 0.0     79028
# 1.0      4695
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: count, dtype: int64

# %%
#fillmissing values of children variable with mean
df['children'].fillna(df['children'].mean(),inplace= True)
# Out:
# <ipython-input-8-a828da1c6143>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['children'].fillna(df['children'].mean(),inplace= True)
# <ipython-input-8-a828da1c6143>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['children'].fillna(df['children'].mean(),inplace= True)

# %%
df['children'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df['country'].isnull().sum()
# Out:
# 452

# %%
df.shape
# Out:
# (87396, 32)

# %%
#percentage of missing values in the country coulumn
country_values = (452/87396)*100
print(country_values)
# Out:
# 0.5171861412421621

# %% [markdown]
# Since only 0.5 percentage of country values are missing it can be replaced by mode inputation.

# %%
df.iloc[10:13,9:]
# Out:
#     adults  children  babies meal country market_segment distribution_channel  \
# 11       2       0.0       0   HB     PRT      Online TA                TA/TO
# 12       2       0.0       0   BB     USA      Online TA                TA/TO
# 13       2       1.0       0   HB     ESP      Online TA                TA/TO
#
#     is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 11                  0                       0                               0
# 12                  0                       0                               0
# 13                  0                       0                               0
#
#     ... deposit_type  agent  company days_in_waiting_list  customer_type  \
# 11  ...   No Deposit  240.0      NaN                    0      Transient
# 12  ...   No Deposit  240.0      NaN                    0      Transient
# 13  ...   No Deposit  241.0      NaN                    0      Transient
#
# ...

# %%
missing_country= df['country'].mode()
print(missing_country)
# Out:
# 0    PRT
# Name: country, dtype: object

# %%
new_country=df['country'][0]
print(new_country)
# Out:
# PRT

# %%
#Filling missing values in the country with mode
df['country'].fillna(new_country,inplace=True)
# Out:
# <ipython-input-13-22cf1c3f14c7>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna(new_country,inplace=True)
# <ipython-input-13-22cf1c3f14c7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'].fillna(new_country,inplace=True)

# %%
df['country']
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 87396, dtype: object

# %%
df['country'].isnull().sum()
# Out:
# 0

# %%
df['agent']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 87396, dtype: float64

# %%
#Filling the missing value with 0 to indicate it is a direct booking
agent_fill=0
df['agent'].fillna(agent_fill,inplace=True)
# Out:
# <ipython-input-15-dabb614d0d69>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['agent'].fillna(agent_fill,inplace=True)
# <ipython-input-15-dabb614d0d69>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agent'].fillna(agent_fill,inplace=True)

# %%
df['agent'].isnull().sum()
# Out:
# 0

# %%
df['agent']=df['agent'].astype(int)
# Out:
# <ipython-input-17-4962160585a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agent']=df['agent'].astype(int)

# %%
df['agent'].dtype
# Out:
# dtype('int64')

# %%
#Filling the missing values in the company with 0 to indicate the direct booking
df['company'].fillna(0,inplace=True)
# Out:
# <ipython-input-19-69b36437b00e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['company'].fillna(0,inplace=True)
# <ipython-input-19-69b36437b00e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['company'].fillna(0,inplace=True)

# %%
df['company'].dtype
# Out:
# dtype('float64')

# %%
df['company'].value_counts()
# Out:
# company
# 0.0      82137
# 40.0       851
# 223.0      503
# 45.0       238
# 153.0      206
#          ...
# 96.0         1
# 76.0         1
# 184.0        1
# 54.0         1
# 402.0        1
# Name: count, Length: 353, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The dataset consist of 119390 rows and 32 columns of which 31994 where duplicated. So the inorder to perform EDA duplicates were removed and check for null values were also made. They were found on varaibles such as children,country,agent,company. Null values on children variable were replace with their median values.Since company and agent representing their identity null values on these variable were imposed by zero to indicate they were direct bookings.
# country varaible represnting the country code,the null values in this was replaced by most frequently occuring value.

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    63371
# 1    24025
# Name: count, dtype: int64

# %%
df['arrival_date_year'].value_counts()
# Out:
# arrival_date_year
# 2016    42391
# 2017    31692
# 2015    13313
# Name: count, dtype: int64

# %%
df_filtered = df[df['is_canceled'] == 0]
sns.countplot(x='arrival_date_year', data=df_filtered)

plt.title("Count of Non-Canceled Bookings Per Year")
plt.ylabel("Number of Bookings")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# In order to compare the ratio of non-cancelled bookings in accordance with different years.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above chart depicts the ratio of non-cancelled bookings.
# There is a significant increase in non-cancelled bookings from 2015 to 2016 and there is a less drop in bookings as it approches 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# By analyzing these patterns, the business can forecast future booking trends and plan for capacity, customer support, and marketing accordingly. Knowing where to expect changes helps in resource optimization.
# Overall, understanding these trends and using them to adjust strategies can indeed lead to more positive outcomes and a more robust business model.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
df_filtered1 = df[df['is_canceled'] == 1]
sns.countplot(x='arrival_date_year', data=df_filtered1,color='orange')

plt.title("Count of Canceled Bookings Per Year")
plt.ylabel("Number of Bookings")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To represent the ratio of cancelled booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Of all the three years the cancelled booking was least in 2015.It may be the reason that hotels might offered attractive discounts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# By analyzing the patterns and root causes behind cancellations, a business can implement changes to reduce them, such as improving the booking process, offering flexible policies, enhancing customer service, or refining marketing strategies

# %% [markdown]
# #### Chart - 3

# %%
new_data=df['hotel'].value_counts()
new_data
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
# Chart - 3 visualization code
plt.pie(x=new_data,labels=new_data.index,colors=['red','green'],autopct='%1.0f%%')
plt.title('Ratio of hotel type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse customer preference towards hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers mostly prefer city type hotel which may be due its cosy ambience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Increasing the count of city type hotel may increase the bussiness growth.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
df_month=df['arrival_date_month'].value_counts()
df_month
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
sns.barplot(x='arrival_date_month',y='count',data=(pd.DataFrame(df_month)),palette='pastel')
plt.title('Month-wise hotel bookings')
plt.xlabel('Month')
plt.ylabel('no of bookings')
plt.xticks(rotation=35)
plt.show()
# Out:
# <ipython-input-51-a8e1663e3f82>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='arrival_date_month',y='count',data=(pd.DataFrame(df_month)),palette='pastel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To find which month has highest no of bookings.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# August month has highest no of bookings as compared with other months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Will the gained insights help creating a positive business impact?
#
# Since this is a high-traffic month, it’s an opportunity to deliver an exceptional experience that can lead to repeat business or referrals. Offering personalized services, streamlined check-ins, and extra perks can help retain customers

# %% [markdown]
# #### Chart - 5

# %%
df['adr'].value_counts()
# Out:
# adr
# 0.00      1778
# 75.00     1320
# 65.00     1260
# 48.00      878
# 85.00      858
#           ...
# 55.11        1
# 33.65        1
# 31.41        1
# 31.80        1
# 157.71       1
# Name: count, Length: 8879, dtype: int64

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,5))
sns.boxplot(x='arrival_date_month',y='adr',data=df,palette='muted')
plt.ylim(0,250)
plt.xticks(rotation=45)
plt.title('Distribution of Average-Daily-Rate')
plt.show()
# Out:
# <ipython-input-33-3b395b6e7c16>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='arrival_date_month',y='adr',data=df,palette='muted')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box-plot is used to represent the distribution and wide-spread of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only july and august months are free from outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Since august and july are free from outliers compared with other months,it is neccessary to reduce the pricing and promote offers for other months in order to grab customers attention and increase the number of bookings.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
data=df['country'].value_counts().nlargest(10)
sns.barplot(x=data.index,y=data.values,palette='viridis')
plt.title('Top 10 countries by hotel booking')
plt.ylabel('Count of bookings')
plt.show()
# Out:
# <ipython-input-28-5f95f6834f1e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index,y=data.values,palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize people from which country prefer outside stays.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Guests from portugal prefer to stay in hotels as compared with other country.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Increasing the hospitality mangement towards portugal guests can increase the no of bookings.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
prt_data=df[(df['country']=='PRT')]
sns.barplot(y=prt_data['meal'].index,x=prt_data['meal'].values,palette='coolwarm')
plt.title('Food type offered by hotels in Portugal')
plt.xlabel('Type of Food')
plt.ylabel('values')
plt.show()
# Out:
# <ipython-input-54-6b1d6161ea7d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=prt_data['meal'].index,x=prt_data['meal'].values,palette='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    63371
# Canceled     23011
# No-Show       1014
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
category=df.groupby(["arrival_date_year", "reservation_status"])["reservation_status"].size().reset_index(name='count')
category
# Out:
#    arrival_date_year reservation_status  count
# 0               2015           Canceled   2549
# 1               2015          Check-Out  10609
# 2               2015            No-Show    155
# 3               2016           Canceled  10638
# 4               2016          Check-Out  31183
# 5               2016            No-Show    570
# 6               2017           Canceled   9824
# 7               2017          Check-Out  21579
# 8               2017            No-Show    289

# %%
sns.lineplot(x='arrival_date_year',y='count',hue='reservation_status',data=pd.DataFrame(category))
plt.xticks([2015,2016,2017])
plt.yscale('log')
plt.title('YearWise Reservation status')
plt.xlabel('year')
plt.ylabel('no of bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze trend pattern related reservation status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Since the check-out status is high, the hotels a accomapiened with steady flow of guest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As the cancellation status is about medium value,the hotels might not have negative profit.

# %% [markdown]
# #### Chart - 9 - Correlation Heatmap

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# Correlation Heatmap visualization code
corr_df=df.drop({'hotel','arrival_date_month','meal','country','market_segment','distribution_channel','reserved_room_type','assigned_room_type',
'deposit_type','customer_type','reservation_status','reservation_status_date'},axis=1)
corr_matrix=corr_df.corr()
plt.figure(figsize=(10, 6))  # Adjust figure size
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=1)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out relationship between variables under study.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There exists negative correlation between many variable and this shows that they are not related with each other.The variables stay_in_week_nights and stay_in_weekend_nights have correlation value of 0.5 this shows that there exist the positive relationship between them.

# %% [markdown]
# #### Chart - 10 - Pair Plot

# %%
select_columns=['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies', 'previous_cancellations',
    'required_car_parking_spaces', 'total_of_special_requests']

# %%
# Pair Plot visualization code

df_pp = df[select_columns]
sns.pairplot(df_pp,diag_kind="hist",plot_kws={'alpha': 0.5, 's': 10})
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the relationship between numerical varaibles through a graphic representation and analyse how each varaible is correlated with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Long lead times often correlate with higher cancellations, suggesting stricter policies may be needed.
# *   Families (with children) prefer weekend stays, while business travelers book longer weekday stays.
#
# *   Parking requests are higher for weekend bookings, indicating self-driving guests.
# *    More special requests align with longer stays, presenting upselling opportunities.
#
# *    More special requests align with longer stays, presenting upselling opportunities. Outliers in lead time or special requests may indicate anomalies or unique booking behaviors.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve business objectives in hotel booking data, focus on reducing cancellations by analyzing guest patterns and implementing stricter policies for high-risk bookings. Increase occupancy rates with dynamic pricing, seasonal promotions, and targeted offers for business and leisure travelers. Enhance customer experience by personalizing services, improving loyalty programs, and addressing negative trends. Optimize distribution channels by encouraging direct bookings and evaluating OTA performance. Leverage predictive analytics to forecast demand, prevent no-shows, and optimize revenue. Implement data-driven dashboards to monitor KPIs and enhance decision-making.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Utilizing hotel booking data helps optimize pricing, increase occupancy, and improve guest satisfaction. By analyzing cancellation patterns, guest preferences, and distribution channels, hotels can implement targeted promotions and loyalty programs. Focusing on direct bookings and leveraging predictive analytics ensures informed decisions, boosting profitability and enhancing the overall guest experience. This data-driven approach drives sustainable growth and success in a competitive market.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
